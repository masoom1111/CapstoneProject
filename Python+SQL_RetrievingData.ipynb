# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # How to Meet and Retrieve Your Data

# %% [markdown]
# Watershed's intern put together a couple of sources of information that will be useful for your project. These three types of information are contained in the capstone database:
# 1. the current monthly rent Watershed charges for all of their client’s 244 properties, as well as the property type and geographic location of those properties.
# 2. some general information about examples of short-term rental properties.  This information can be used to get a sense of what kind of nightly rental price Watershed’s client’s properties *could* be listed for, if they were converted to short-term rentals.
# 3. records about when those short-term rental properties were rented out, so that you can calculate their occupancy rates.

# %% [markdown]
# Your job is to determine how the database is organized so that you can retrieve all of the available information about Watershed’s client’s 244 properties, as well as the corresponding short-term rental information for comparable properties in the same location and of the same type.
# 1. Start by determining what tables the database contains, and what fields are included in each table.
# 2. Then, we recommend that you make at least a rough relational schema of how the database is organized, so that you know what fields you can use to join tables.
# 3. Next, make a list of the columns of data you want to retrieve in your final output.
# 4. Finally, write your query to retrieve the desired data from the database.

# %% [markdown]
# Here are some hints about how to write your query:
# * Start by joining no more than two tables.  After you have made sure the query works as written and that the output makes sense, add other tables one at a time, checking the new query and its results each time.
# * Your final output should have 244 rows.  Given the limited output, the easiest way to extract the results will be to copy and paste the output from your query into Excel, although you could also extract as a .csv file and open that with Excel.  If you choose the .csv option, you might find it necessary to write your query on multiple lines when you declare it as a variable.  To do this, type a space (if you forget the space the lines will run together) and a "\" at the end of each line of your query:
#
# ```
# my_data= %sql SELECT DISTINCT user_guid, state, membership_type \
# FROM users \
# WHERE country="US" AND state IS NOT NULL and membership_type IS NOT NULL \
# ORDER BY state ASC, membership_type ASC ;
#
# my_data.csv('my_data.csv')
# ```
#
# * We recommend that you calculate the occupancy rates of the example short-term rental properties within MySQL, rather than within Excel (it will be much faster!)  To do this, only examine rental dates during 2015, and remember that there are 365 days in the year.  The final output of your calculation should be the percentage of days in 2015 that the property was occupied.  You may want to consider using a subquery for this calculation.
# * Make sure that you extract information from short-term rentals <u>**_that have the same location and property type_**</u> as the 244 Watershed properties.
# * If you run into trouble, use your workbooks and Teradata notes from “Managing Big Data with MySQL” to remind you how to implement different parts of your query.
#
# <img src="https://duke.box.com/shared/static/svbdzasxe7nncnszps6ewnkr8og4798c.jpg" width="300" alt="SQL Master"/>

# %% [markdown]
# ## Good luck and have fun!

# %% [markdown]
# To get started, connect to the capstone database and set the database as your default database using the following commands:
#
# ```python
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/capstone
# %sql USE capstone
# ```

# %% [markdown]
# ### Load and connect to the database

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/capstone 
# %sql USE capstone
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 0 rows affected.
# []

# %% [markdown]
# ### Queries
#
# You can add as many "cells" as you need in order to explore the database and extract the appropriate data.  For a reminder about what "cells" are, how to add them, or how to use Jupyter in general, please refer to the "How to Use Jupyter Notebooks" video at: https://www.coursera.org/learn/analytics-mysql/lecture/oxkUg/how-to-use-jupyter-notebooks.

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 6 rows affected.
# [('location',),
#  ('property_type',),
#  ('st_property_info',),
#  ('st_rental_dates',),
#  ('st_rental_prices',),
#  ('watershed_property_info',)]

# %%
# %%sql
# SELECT * FROM location limit 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('L1', 'Anchorage', 'AK', 99501),
#  ('L10', 'Anchorage', 'AK', 99518),
#  ('L100', 'Cherokee', 'AL', 35616),
#  ('L1000', 'Azusa', 'CA', 91702),
#  ('L10000', 'Winston-Sa', 'NC', 27101)]

# %%
# %%sql
# SELECT * FROM property_type;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 16 rows affected.
# [('R1', 'apartment', '1', 'Y', 'Y'),
#  ('R10', 'house', '1', 'Y', 'N'),
#  ('R11', 'house', '1', 'N', 'Y'),
#  ('R12', 'house', '1', 'N', 'N'),
#  ('R13', 'house', '2', 'Y', 'Y'),
#  ('R14', 'house', '2', 'Y', 'N'),
#  ('R15', 'house', '2', 'N', 'Y'),
#  ('R16', 'house', '2', 'N', 'N'),
#  ('R2', 'apartment', '1', 'Y', 'N'),
#  ('R3', 'apartment', '1', 'N', 'Y'),
#  ('R4', 'apartment', '1', 'N', 'N'),
#  ('R5', 'apartment', '2', 'Y', 'Y'),
#  ('R6', 'apartment', '2', 'Y', 'N'),
#  ('R7', 'apartment', '2', 'N', 'Y'),
#  ('R8', 'apartment', '2', 'N', 'N'),
#  ('R9', 'house', '1', 'Y', 'Y')]

# %%
# %%sql
# SELECT * FROM st_property_info limit 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('ST1', 'L9531', 'R6'),
#  ('ST10', 'L9533', 'R6'),
#  ('ST100', 'L1944', 'R2'),
#  ('ST1000', 'L5957', 'R1'),
#  ('ST101', 'L15257', 'R2')]

# %%
# %%sql
# SELECT * FROM st_rental_dates limit 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [(datetime.date(2014, 1, 31), 'ST100'),
#  (datetime.date(2014, 1, 31), 'ST106'),
#  (datetime.date(2014, 1, 31), 'ST107'),
#  (datetime.date(2014, 1, 31), 'ST109'),
#  (datetime.date(2014, 1, 31), 'ST113')]

# %%
# %%sql
# SELECT * FROM st_rental_prices limit 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('L10126', 'R1', 83, 273, 192),
#  ('L10126', 'R10', 155, 494, 257),
#  ('L10126', 'R11', 82, 411, 242),
#  ('L10126', 'R12', 119, 366, 229),
#  ('L10126', 'R13', 137, 416, 375)]

# %%
# %%sql
# SELECT * FROM watershed_property_info limit 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('W1', 'L9531', 'R6', 1060),
#  ('W10', 'L9533', 'R6', 1200),
#  ('W100', 'L1944', 'R2', 3300),
#  ('W101', 'L15257', 'R2', 1400),
#  ('W102', 'L15257', 'R6', 2000)]

# %%
# %%sql
# desc location;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 4 rows affected.
# [('location_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zipcode', 'int(5)', 'YES', '', None, '')]

# %%
# %%sql
# desc property_type;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('property_type_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('apt_house', 'varchar(255)', 'YES', '', None, ''),
#  ('num_bedrooms', 'varchar(255)', 'YES', '', None, ''),
#  ('kitchen', 'varchar(255)', 'YES', '', None, ''),
#  ('shared', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# desc st_property_info;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 3 rows affected.
# [('st_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, '')]

# %%
# %%sql
# desc st_rental_dates;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 2 rows affected.
# [('rental_date', 'date', 'NO', 'PRI', None, ''),
#  ('st_property', 'varchar(255)', 'NO', 'PRI', None, '')]

# %%
# %%sql
# desc st_rental_prices;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('location', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('property_type', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('percentile_10th_price', 'int(11)', 'YES', '', None, ''),
#  ('percentile_90th_price', 'int(11)', 'YES', '', None, ''),
#  ('sample_nightly_rent_price', 'int(11)', 'YES', '', None, '')]

# %%
# %%sql
# desc watershed_property_info;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 4 rows affected.
# [('ws_property_id', 'varchar(255)', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(255)', 'YES', '', None, ''),
#  ('property_type', 'varchar(255)', 'YES', '', None, ''),
#  ('current_monthly_rent', 'int(11)', 'NO', '', None, '')]

# %%
# %%sql
# SELECT wpi.ws_property_id, wpi.location, wpi.property_type, wpi.current_monthly_rent, stpi.st_property_id
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('W1', 'L9531', 'R6', 1060, 'ST1'),
#  ('W10', 'L9533', 'R6', 1200, 'ST10'),
#  ('W100', 'L1944', 'R2', 3300, 'ST100'),
#  ('W101', 'L15257', 'R2', 1400, 'ST101'),
#  ('W102', 'L15257', 'R6', 2000, 'ST102')]

# %%
# %%sql
# SELECT wpi.ws_property_id, wpi.location, wpi.property_type, wpi.current_monthly_rent, stpi.st_property_id, strp.sample_nightly_rent_price
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_prices strp
# ON stpi.location=strp.location and stpi.property_type=strp.property_type
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('W1', 'L9531', 'R6', 1060, 'ST1', 148),
#  ('W10', 'L9533', 'R6', 1200, 'ST10', 133),
#  ('W100', 'L1944', 'R2', 3300, 'ST100', 372),
#  ('W101', 'L15257', 'R2', 1400, 'ST101', 302),
#  ('W102', 'L15257', 'R6', 2000, 'ST102', 429)]

# %%
# %%sql
# SELECT wpi.ws_property_id, wpi.location, wpi.property_type, wpi.current_monthly_rent, strp.sample_nightly_rent_price, pt.apt_house,pt.num_bedrooms,pt.kitchen,pt.shared
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_prices strp
# ON stpi.location=strp.location and stpi.property_type=strp.property_type
# JOIN
# property_type pt
# ON stpi.property_type=pt.property_type_id
# ORDER BY ws_property_id
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('W1', 'L9531', 'R6', 1060, 148, 'apartment', '2', 'Y', 'N'),
#  ('W10', 'L9533', 'R6', 1200, 133, 'apartment', '2', 'Y', 'N'),
#  ('W100', 'L1944', 'R2', 3300, 372, 'apartment', '1', 'Y', 'N'),
#  ('W101', 'L15257', 'R2', 1400, 302, 'apartment', '1', 'Y', 'N'),
#  ('W102', 'L15257', 'R6', 2000, 429, 'apartment', '2', 'Y', 'N')]

# %%
# %%sql
# SELECT wpi.ws_property_id, wpi.location, wpi.property_type, wpi.current_monthly_rent, strp.sample_nightly_rent_price, pt.apt_house,pt.num_bedrooms,pt.kitchen,pt.shared
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_prices strp
# ON stpi.location=strp.location and stpi.property_type=strp.property_type
# JOIN
# property_type pt
# ON stpi.property_type=pt.property_type_id
# ORDER BY ws_property_id;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('W1', 'L9531', 'R6', 1060, 148, 'apartment', '2', 'Y', 'N'),
#  ('W10', 'L9533', 'R6', 1200, 133, 'apartment', '2', 'Y', 'N'),
#  ('W100', 'L1944', 'R2', 3300, 372, 'apartment', '1', 'Y', 'N'),
#  ('W101', 'L15257', 'R2', 1400, 302, 'apartment', '1', 'Y', 'N'),
#  ('W102', 'L15257', 'R6', 2000, 429, 'apartment', '2', 'Y', 'N'),
#  ('W103', 'L15257', 'R10', 1600, 380, 'house', '1', 'Y', 'N'),
#  ('W104', 'L15257', 'R14', 2800, 374, 'house', '2', 'Y', 'N'),
#  ('W105', 'L15260', 'R2', 1100, 386, 'apartment', '1', 'Y', 'N'),
#  ('W106', 'L15260', 'R6', 1900, 212, 'apartment', '2', 'Y', 'N'),
#  ('W107', 'L15260', 'R10', 1800, 969, 'house', '1', 'Y', 'N'),
#  ('W108', 'L15260', 'R14', 3200, 885, 'house', '2', 'Y', 'N'),
#  ('W109', 'L15264', 'R2', 1000, 287, 'apartment', '1', 'Y', 'N'),
#  ('W11', 'L9533', 'R10', 1000, 206, 'house', '1', 'Y', 'N'),
#  ('W110', 'L15264', 'R6', 1300, 462, 'apartment', '2', 'Y', 'N'),
# ...

# %%
# %%sql
# SELECT loc.location_id,loc.city,loc.state,loc.zipcode,strp.location, strp.sample_nightly_rent_price
# from location loc
# JOIN
# st_rental_prices strp
# ON
# strp.location = loc.location_id
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('L10126', 'Omaha', 'NE', 68046, 'L10126', 192),
#  ('L10126', 'Omaha', 'NE', 68046, 'L10126', 257),
#  ('L10126', 'Omaha', 'NE', 68046, 'L10126', 242),
#  ('L10126', 'Omaha', 'NE', 68046, 'L10126', 229),
#  ('L10126', 'Omaha', 'NE', 68046, 'L10126', 375)]

# %%
# %%sql
# SELECT * from st_rental_dates
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [(datetime.date(2014, 1, 31), 'ST100'),
#  (datetime.date(2014, 1, 31), 'ST106'),
#  (datetime.date(2014, 1, 31), 'ST107'),
#  (datetime.date(2014, 1, 31), 'ST109'),
#  (datetime.date(2014, 1, 31), 'ST113')]

# %%
# %%sql
# DESC st_rental_dates;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 2 rows affected.
# [('rental_date', 'date', 'NO', 'PRI', None, ''),
#  ('st_property', 'varchar(255)', 'NO', 'PRI', None, '')]

# %%
# %%sql
# SELECT * from st_rental_dates
# WHERE rental_date >= '2015-01-01'
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [(datetime.date(2015, 1, 1), 'ST1'),
#  (datetime.date(2015, 1, 1), 'ST1000'),
#  (datetime.date(2015, 1, 1), 'ST105'),
#  (datetime.date(2015, 1, 1), 'ST106'),
#  (datetime.date(2015, 1, 1), 'ST108')]

# %%
# %%sql
# SELECT wpi.ws_property_id, loc.location_id, loc.city, loc.state, loc.zipcode, pt.apt_house, pt.num_bedrooms, pt.kitchen, pt.shared, wpi.current_monthly_rent, strp.percentile_10th_price, strp.percentile_90th_price, strd.rental_date
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_prices strp
# ON stpi.location=strp.location and stpi.property_type=strp.property_type
# JOIN
# property_type pt
# ON stpi.property_type=pt.property_type_id
# JOIN
# location loc
# ON strp.location=loc.location_id
# JOIN
# st_rental_dates strd
# ON
# stpi.st_property_id=strd.st_property
# WHERE strd.rental_date > '2015-01-01'
# ORDER BY ws_property_id
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, datetime.date(2015, 1, 6)),
#  ('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, datetime.date(2015, 1, 7)),
#  ('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, datetime.date(2015, 1, 14)),
#  ('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, datetime.date(2015, 1, 23)),
#  ('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, datetime.date(2015, 1, 28))]

# %%
# %%sql
# SELECT wpi.ws_property_id, loc.location_id, loc.city, loc.state, loc.zipcode, pt.apt_house, pt.num_bedrooms, pt.kitchen, pt.shared, wpi.current_monthly_rent, strp.percentile_10th_price, strp.percentile_90th_price, strd.rental_date
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_prices strp
# ON stpi.location=strp.location and stpi.property_type=strp.property_type
# JOIN
# property_type pt
# ON stpi.property_type=pt.property_type_id
# JOIN
# location loc
# ON strp.location=loc.location_id
# JOIN
# st_rental_dates strd
# ON
# stpi.st_property_id=strd.st_property
# WHERE strd.rental_date > '2015-01-01'
# ORDER BY ws_property_id
# LIMIT 1;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 1 rows affected.
# [('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, datetime.date(2015, 1, 6))]

# %%
# %%sql
# SELECT wpi.ws_property_id, stpi.location, stpi.property_type, strd.rental_date,
# FROM watershed_property_info wpi
# LEFT JOIN
# st_property_info stpi
# ON wpi.location=stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_dates strd
# ON stpi.st_property_id=strd.st_property
# WHERE strd.rental_date >= '2015-01-01'
# LIMIT 5;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 5 rows affected.
# [('W1', 'L9531', 'R6', datetime.date(2015, 1, 1)),
#  ('W105', 'L15260', 'R2', datetime.date(2015, 1, 1)),
#  ('W106', 'L15260', 'R6', datetime.date(2015, 1, 1)),
#  ('W108', 'L15260', 'R14', datetime.date(2015, 1, 1)),
#  ('W112', 'L15264', 'R14', datetime.date(2015, 1, 1))]

# %% [markdown]
# Capstone_data=%sql
# SELECT DISTINCT w.ws_property_id,w.location, w.property_type,w.current_monthly_rent,srp.percentile_10th_price,srp.percentile_90th_price,srp.sample_nightly_rent_price,srd.rental_date,srd.st_property, COUNT(srd.rental_date)/365 AS occupancy_rate,p.apt_house,p.num_bedrooms,p.kitchen,p.shared,l.city,l.state,l.zipcode
# FROM watershed_property_info w
# JOIN st_property_info spi
# ON (w.location=spi.location AND w.property_type=spi.property_type)
# JOIN st_rental_prices srp
# ON (spi.location=srp.location AND spi.property_type=srp.property_type)
# JOIN property_type p
# ON w.property_type=p.property_type_id
# JOIN location l
# ON w.location=l.location_id
# JOIN st_rental_dates srd
# ON spi.st_property_id = srd.st_property
# WHERE YEAR(srd.rental_date)=2015 GROUP BY srd.st_property

# %%
# %%sql
# SELECT DISTINCT wpi.ws_property_id, loc.location_id, loc.city, loc.state, loc.zipcode, pt.apt_house, pt.num_bedrooms, pt.kitchen, pt.shared, wpi.current_monthly_rent, strp.percentile_10th_price, strp.percentile_90th_price, strp.sample_nightly_rent_price, strd.rental_date, strd.st_property, COUNT(strd.rental_date)/365 AS occupancy_rate
# FROM watershed_property_info wpi
# JOIN
# st_property_info stpi
# ON wpi.location = stpi.location and wpi.property_type=stpi.property_type
# JOIN
# st_rental_prices strp
# ON stpi.location=strp.location and stpi.property_type=strp.property_type
# JOIN
# property_type pt
# ON stpi.property_type=pt.property_type_id
# JOIN
# location loc
# ON strp.location=loc.location_id
# JOIN
# st_rental_dates strd
# ON
# stpi.st_property_id=strd.st_property
# WHERE YEAR(strd.rental_date)=2015
# GROUP BY strd.st_property;
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# [('W1', 'L9531', 'Chapel Hill', 'NC', 27514, 'apartment', '2', 'Y', 'N', 1060, 114, 153, 148, datetime.date(2015, 1, 1), 'ST1', Decimal('0.1616')),
#  ('W10', 'L9533', 'Chapel Hill', 'NC', 27517, 'apartment', '2', 'Y', 'N', 1200, 111, 149, 133, datetime.date(2015, 1, 5), 'ST10', Decimal('0.3479')),
#  ('W100', 'L1944', 'San Francisco', 'CA', 94129, 'apartment', '1', 'Y', 'N', 3300, 108, 610, 372, datetime.date(2015, 1, 7), 'ST100', Decimal('0.3973')),
#  ('W101', 'L15257', 'Austin', 'TX', 78702, 'apartment', '1', 'Y', 'N', 1400, 178, 533, 302, datetime.date(2015, 1, 2), 'ST101', Decimal('0.3644')),
#  ('W102', 'L15257', 'Austin', 'TX', 78702, 'apartment', '2', 'Y', 'N', 2000, 221, 617, 429, datetime.date(2015, 1, 4), 'ST102', Decimal('0.4110')),
#  ('W103', 'L15257', 'Austin', 'TX', 78702, 'house', '1', 'Y', 'N', 1600, 202, 646, 380, datetime.date(2015, 1, 4), 'ST103', Decimal('0.4110')),
# ...

# %%
final_output= %sql \
SELECT DISTINCT wpi.ws_property_id, loc.location_id, wpi.property_type, loc.city, loc.state, loc.zipcode, pt.apt_house, pt.num_bedrooms, pt.kitchen, pt.shared, wpi.current_monthly_rent, strp.percentile_10th_price, strp.percentile_90th_price, strp.sample_nightly_rent_price, strd.rental_date, strd.st_property, COUNT(strd.rental_date)/365 AS occupancy_rate \
FROM watershed_property_info wpi\
JOIN \
st_property_info stpi \
ON wpi.location = stpi.location and wpi.property_type=stpi.property_type \
JOIN \
st_rental_prices strp \
ON stpi.location=strp.location and stpi.property_type=strp.property_type \
JOIN \
property_type pt \
ON stpi.property_type=pt.property_type_id \
JOIN \
location loc \
ON strp.location=loc.location_id \
JOIN \
st_rental_dates strd \
ON \
stpi.st_property_id=strd.st_property \
WHERE YEAR(strd.rental_date)=2015 \
GROUP BY strd.st_property; 

final_output.csv('final_output.csv')
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# CSV results at /home/jovyan/work/final_output.csv

# %%
Watershed_database= %sql \
SELECT DISTINCT wpi.ws_property_id, loc.location_id, wpi.property_type, loc.city, loc.state, loc.zipcode, pt.apt_house, pt.num_bedrooms, pt.kitchen, pt.shared, wpi.current_monthly_rent, strp.percentile_10th_price, strp.percentile_90th_price, strp.sample_nightly_rent_price, strd.rental_date, strd.st_property, COUNT(strd.rental_date)/365 AS occupancy_rate \
FROM watershed_property_info wpi\
JOIN \
st_property_info stpi \
ON wpi.location = stpi.location and wpi.property_type=stpi.property_type \
JOIN \
st_rental_prices strp \
ON stpi.location=strp.location and stpi.property_type=strp.property_type \
JOIN \
property_type pt \
ON stpi.property_type=pt.property_type_id \
JOIN \
location loc \
ON strp.location=loc.location_id \
JOIN \
st_rental_dates strd \
ON \
stpi.st_property_id=strd.st_property \
WHERE YEAR(strd.rental_date)=2015 \
GROUP BY strd.st_property; 

Watershed_database.csv('Watershed_database.csv')
# Out:
#  * mysql://studentuser:***@localhost/capstone
# 244 rows affected.
# CSV results at /home/jovyan/work/Watershed_database.csv
